# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 994 kB 640 kB/s eta 0:00:01
# ...
#   Using cached Fiona-1.8.20-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (15.4 MB)
# ...
#   Using cached pyproj-3.1.0-cp38-cp38-manylinux2010_x86_64.whl (6.6 MB)
# ...
#   Using cached munch-2.5.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# ...
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# ...

# %%
import geopandas
import pandas as pd

# %%
df=pd.read_csv('../raw_data/bpe_t2_clean.csv')
df.head()
# Out:
#    Unnamed: 0   iris_id iris_type  iris_with_t1  iris_with_t2    AN  \
# 0           0  61230102         H             0             1  2018
# 1           1  61230102         H             0             1  2018
# 2           2  61230102         H             0             1  2018
# 3           3  61230102         H             0             1  2018
# 4           4  60880301         H             1             1  2018
#
#    longitude   latitude  ('LAB', 'is_sport')  ('LAB', 'is_leasure')  ...  \
# 0   7.178602  43.658636                    0                      1  ...
# 1   7.178602  43.658636                    0                      0  ...
# 2   7.178602  43.658636                    0                      0  ...
# 3   7.178602  43.658636                    0                      0  ...
# 4   7.283691  43.706875                    0                      0  ...
#
#    ('LAB', 'is_commerce_spec')  ('LAB', 'is_grande_surface')  \
# ...

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'iris_id',
#  'iris_type',
#  'iris_with_t1',
#  'iris_with_t2',
#  'AN',
#  'longitude',
#  'latitude',
#  "('LAB', 'is_sport')",
#  "('LAB', 'is_leasure')",
#  "('LAB', 'is_medical')",
#  "('LAB', 'is_socio_med')",
#  "('LAB', 'is_tourist')",
#  "('LAB', 'is_general_service')",
#  "('LAB', 'is_commerce')",
#  "('LAB', 'is_commerce_spec')",
#  "('LAB', 'is_grande_surface')",
#  "('LAB', 'is_high_educ')",
#  "('LAB', 'is_schools')",
#  "('LAB', 'is_transport')",
#  'Q_XY_acceptable',
#  'Q_XY_bonne',
#  'Q_XY_mauvaise',
#  'LAB',
#  'CLASSE']
